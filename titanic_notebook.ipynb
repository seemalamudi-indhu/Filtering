# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\iseemala\\Downloads\\titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
netflix=pd.read_csv(r"C:\Users\iseemala\Downloads\netflix_titles.csv",index_col=0)

# %%
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Exercise
import pandas
bestsellers=pandas.read_csv(r"C:\Users\iseemala\Downloads\bestsellers.csv")

# %%
bestsellers
# Out:
#       published_date                      list_name  \
# 0         2010-01-03                  Chapter Books
# 1         2010-01-03                  Chapter Books
# 2         2010-01-03                  Chapter Books
# 3         2010-01-03                  Chapter Books
# 4         2010-01-03                  Chapter Books
# ...              ...                            ...
# 61425     2019-12-29  Young Adult Paperback Monthly
# 61426     2019-12-29  Young Adult Paperback Monthly
# 61427     2019-12-29  Young Adult Paperback Monthly
# 61428     2019-12-29  Young Adult Paperback Monthly
# 61429     2019-12-29  Young Adult Paperback Monthly
#
#                    list_name_encoded  rank         isbn13      isbn10  \
# 0                      chapter-books     1  9780316036245  0316036242
# 1                      chapter-books     2  9780439023481  0439023483
# 2                      chapter-books     3  9780439023498  0439023491
# ...

# %%
bestsellers.head()
# Out:
#   published_date      list_name list_name_encoded  rank         isbn13  \
# 0     2010-01-03  Chapter Books     chapter-books     1  9780316036245
# 1     2010-01-03  Chapter Books     chapter-books     2  9780439023481
# 2     2010-01-03  Chapter Books     chapter-books     3  9780439023498
# 3     2010-01-03  Chapter Books     chapter-books     4  9780763644109
# 4     2010-01-03  Chapter Books     chapter-books     5  9780385738934
#
#        isbn10                    title  \
# 0  0316036242         WITCH AND WIZARD
# 1  0439023483         THE HUNGER GAMES
# 2  0439023491            CATCHING FIRE
# 3  0763644102  THE MAGICIAN’S ELEPHANT
# 4  0385738935                   FALLEN
#
#                                      author  \
# 0  James Patterson and Gabrielle Charbonnet
# 1                           Suzanne Collins
# 2                           Suzanne Collins
# 3                            Kate DiCamillo
# 4                               Lauren Kate
#
# ...

# %%
bestsellers.head(20)
# Out:
#    published_date                list_name        list_name_encoded  rank  \
# 0      2010-01-03            Chapter Books            chapter-books     1
# 1      2010-01-03            Chapter Books            chapter-books     2
# 2      2010-01-03            Chapter Books            chapter-books     3
# 3      2010-01-03            Chapter Books            chapter-books     4
# 4      2010-01-03            Chapter Books            chapter-books     5
# 5      2010-01-03         Hardcover Advice         hardcover-advice     1
# 6      2010-01-03         Hardcover Advice         hardcover-advice     2
# 7      2010-01-03         Hardcover Advice         hardcover-advice     3
# 8      2010-01-03         Hardcover Advice         hardcover-advice     4
# 9      2010-01-03         Hardcover Advice         hardcover-advice     5
# 10     2010-01-03        Hardcover Fiction        hardcover-fiction     1
# 11     2010-01-03        Hardcover Fiction        hardcover-fiction     2
# ...

# %%
bestsellers.tail()
# Out:
#       published_date                      list_name  \
# 61425     2019-12-29  Young Adult Paperback Monthly
# 61426     2019-12-29  Young Adult Paperback Monthly
# 61427     2019-12-29  Young Adult Paperback Monthly
# 61428     2019-12-29  Young Adult Paperback Monthly
# 61429     2019-12-29  Young Adult Paperback Monthly
#
#                    list_name_encoded  rank         isbn13      isbn10  \
# 61425  young-adult-paperback-monthly     1  9780142412145  0142412147
# 61426  young-adult-paperback-monthly     2  9780593109069  0593109066
# 61427  young-adult-paperback-monthly     3  9781481438261  1481438263
# 61428  young-adult-paperback-monthly     4  9780553496710  0553496719
# 61429  young-adult-paperback-monthly     5  9780525555377  0525555374
#
#                           title  \
# 61425               LET IT SNOW
# 61426        LOOKING FOR ALASKA
# 61427             LONG WAY DOWN
# 61428    THE SUN IS ALSO A STAR
# 61429  TURTLES ALL THE WAY DOWN
#
# ...

# %%
bestsellers.tail(2)
# Out:
#       published_date                      list_name  \
# 61428     2019-12-29  Young Adult Paperback Monthly
# 61429     2019-12-29  Young Adult Paperback Monthly
#
#                    list_name_encoded  rank         isbn13      isbn10  \
# 61428  young-adult-paperback-monthly     4  9780553496710  0553496719
# 61429  young-adult-paperback-monthly     5  9780525555377  0525555374
#
#                           title       author description  \
# 61428    THE SUN IS ALSO A STAR  Nicola Yoon         NaN
# 61429  TURTLES ALL THE WAY DOWN   John Green         NaN
#
#                                       amazon_product_url  price  weeks_on_list
# 61428  https://www.amazon.com/Sun-Also-Star-Nicola-Yo...    0.0              0
# 61429  https://www.amazon.com/Turtles-All-Down-John-G...    0.0              0

# %%
missing_values=bestsellers.isnull().sum()

# %%
column_with_missingvalues=missing_values[missing_values>0]

# %%
column_with_missingvalues
# Out:
# isbn13            4
# isbn10         3453
# author           69
# description    8119
# dtype: int64

# %%
bestsellers.dtypes
# Out:
# published_date         object
# list_name              object
# list_name_encoded      object
# rank                    int64
# isbn13                 object
# isbn10                 object
# title                  object
# author                 object
# description            object
# amazon_product_url     object
# price                 float64
# weeks_on_list           int64
# dtype: object

# %%
integer_columns=bestsellers.select_dtypes(include="int64")

# %%
integer_columns
# Out:
#        rank  weeks_on_list
# 0         1              1
# 1         2             67
# 2         3             16
# 3         4             15
# 4         5              2
# ...     ...            ...
# 61425     1              0
# 61426     2              0
# 61427     3              0
# 61428     4              0
# 61429     5              0
#
# [61430 rows x 2 columns]

# %%
num_integer_columns=integer_columns.columns

# %%
num_integer_columns
# Out:
# Index(['rank', 'weeks_on_list'], dtype='object')

# %%
len(integer_columns.columns)
# Out:
# 2

# %%
bestsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61430 entries, 0 to 61429
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   published_date      61430 non-null  object
#  1   list_name           61430 non-null  object
#  2   list_name_encoded   61430 non-null  object
#  3   rank                61430 non-null  int64
#  4   isbn13              61426 non-null  object
#  5   isbn10              57977 non-null  object
#  6   title               61430 non-null  object
#  7   author              61361 non-null  object
#  8   description         53311 non-null  object
#  9   amazon_product_url  61430 non-null  object
#  10  price               61430 non-null  float64
#  11  weeks_on_list       61430 non-null  int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 5.6+ MB

# %%
type(bestsellers)
# Out:
# pandas.core.frame.DataFrame

# %%
numeric_columns_sum=bestsellers.select_dtypes(include="number").sum()

# %%
numeric_columns_sum
# Out:
# rank              184290.00
# price             237308.26
# weeks_on_list    1517706.00
# dtype: float64

# %%
bestsellers.sum(numeric_only=True)
# Out:
# rank              184290.00
# price             237308.26
# weeks_on_list    1517706.00
# dtype: float64

# %%
import pandas as pd
titanic=pd.read_csv(r"C:\Users\iseemala\Downloads\titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.select_dtypes(include="int64").sum()
# Out:
# PassengerId    397386
# Survived          342
# Pclass           2057
# SibSp             466
# Parch             340
# dtype: int64

# %%
titanic.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# 10 10 20 30 40 50

# %%
10+10+20+30+40+50
# Out:
# 160

# %%
160/6
# Out:
# 26.666666666666668

# %%
titanic.select_dtypes(include="int64").mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# SibSp            0.523008
# Parch            0.381594
# dtype: float64

# %%
titanic.mode()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 886          887       NaN     NaN                de Mulder, Mr. Theodore
# 887          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 888          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 889          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 890          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#       Sex   Age  SibSp  Parch    Ticket  Fare        Cabin Embarked
# ...

# %%
titanic.mode(numeric_only=True)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# 0              1       0.0     3.0  24.0    0.0    0.0  8.05
# 1              2       NaN     NaN   NaN    NaN    NaN   NaN
# 2              3       NaN     NaN   NaN    NaN    NaN   NaN
# 3              4       NaN     NaN   NaN    NaN    NaN   NaN
# 4              5       NaN     NaN   NaN    NaN    NaN   NaN
# ..           ...       ...     ...   ...    ...    ...   ...
# 886          887       NaN     NaN   NaN    NaN    NaN   NaN
# 887          888       NaN     NaN   NaN    NaN    NaN   NaN
# 888          889       NaN     NaN   NaN    NaN    NaN   NaN
# 889          890       NaN     NaN   NaN    NaN    NaN   NaN
# 890          891       NaN     NaN   NaN    NaN    NaN   NaN
#
# [891 rows x 7 columns]

# %%
titanic.median(numeric_only=True)
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe(include=["object","int64"])
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#              SibSp       Parch  Ticket    Cabin Embarked
# ...

# %%
import pandas as pd
titanic=pd.read_csv(r"C:\Users\iseemala\Downloads\titanic.csv")
netflix=pd.read_csv(r"C:\Users\iseemala\Downloads\netflix_titles.csv")
bestsellers=pd.read_csv(r"C:\Users\iseemala\Downloads\bestsellers.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(titanic.Name)
# Out:
# pandas.core.series.Series

# %%
titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Ticket"]
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
titanic.sum(numeric_only=True)
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Pclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %%
titanic.min(numeric_only=True)
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
titanic.max(numeric_only=True)
# Out:
# PassengerId    891.0000
# Survived         1.0000
# Pclass           3.0000
# Age             80.0000
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
mins=titanic.min(numeric_only=True)

# %%
mins.values
# Out:
# array([1.  , 0.  , 1.  , 0.42, 0.  , 0.  , 0.  ])

# %%
mins.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
titanic.Age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.describe
# Out:
# <bound method NDFrame.describe of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.release_year.head()
# Out:
# 0    2020
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: release_year, dtype: int64

# %%
netflix.title.dtypes
# Out:
# dtype('O')

# %%
netflix["title"].unique()
# Out:
# array(['Dick Johnson Is Dead', 'Blood & Water', 'Ganglands', ...,
#        'Zombieland', 'Zoom', 'Zubaan'], dtype=object)

# %%
netflix.rating
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix.rating.nunique()
# Out:
# 17

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.rating.nunique(dropna=False)
# Out:
# 18

# %%
titanic.Fare.nlargest()
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# 27     263.0000
# 88     263.0000
# Name: Fare, dtype: float64

# %%
titanic.Fare.nsmallest()
# Out:
# 179    0.0
# 263    0.0
# 271    0.0
# 277    0.0
# 302    0.0
# Name: Fare, dtype: float64

# %%
titanic["Name"].value_counts()
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %%
netflix.title.value_counts()
# Out:
# title
# Dick Johnson Is Dead                     1
# Ip Man 2                                 1
# Hannibal Buress: Comedy Camisado         1
# Turbo FAST                               1
# Masha's Tales                            1
#                                         ..
# Love for Sale 2                          1
# ROAD TO ROMA                             1
# Good Time                                1
# Captain Underpants Epic Choice-o-Rama    1
# Zubaan                                   1
# Name: count, Length: 8807, dtype: int64

# %%
netflix.title
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
netflix.director.value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
netflix.director.value_counts(ascending=True).head(10)
# Out:
# director
# Kirsten Johnson                  1
# Evgeny Afineevsky                1
# Kristina Goolsby, Ashley York    1
# Phil Joanou                      1
# Anthony Pierce                   1
# Jennifer Phang                   1
# Jill Bauer, Ronna Gradus         1
# Mike Fleiss                      1
# Aziz Ansari                      1
# David Sampliner                  1
# Name: count, dtype: int64

# %%
netflix[["director","director"]]
# Out:
#              director         director
# 0     Kirsten Johnson  Kirsten Johnson
# 1                 NaN              NaN
# 2     Julien Leclercq  Julien Leclercq
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 8802    David Fincher    David Fincher
# 8803              NaN              NaN
# 8804  Ruben Fleischer  Ruben Fleischer
# 8805     Peter Hewitt     Peter Hewitt
# 8806      Mozez Singh      Mozez Singh
#
# [8807 rows x 2 columns]

# %%
type(netflix[["director","director"]])
# Out:
# pandas.core.frame.DataFrame

# %%
netflix.release_year.plot()
# Out:
# <Axes: >

# %%
netflix.release_year.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='release_year'>

# %%
netflix.release_year.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[["Survived","Name"]].plot()
# Out:
# <Axes: >

# %%
titanic[["Survived","Pclass"]]
df.plot(x="Pclass",y="Survived")
df.plot(kind="scatter",x="Pclass",y="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
titanic.sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.sort_values("Age" ,ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.sort_values("Age" ,ascending=False, inplace=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.sort_values(["Survived","Pclass"],ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 483          484         1       3
# 338          339         1       3
# 414          415         1       3
# 400          401         1       3
# 25            26         1       3
# ..           ...       ...     ...
# 633          634         0       1
# 711          712         0       1
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 483                             Turkula, Mrs. (Hedwig)  female  63.0      0
# 338                              Dahl, Mr. Karl Edwart    male  45.0      0
# 414                          Sundman, Mr. Johan Julian    male  44.0      0
# 400                                 Niskanen, Mr. Juha    male  39.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_index(ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.Pclass.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic.Pclass.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic.Pclass.value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
titanic["Ticket"].loc

# %%
titanic.loc[[]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 titanic.loc[["Dooley, Mr. Patrick"]]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# ...
